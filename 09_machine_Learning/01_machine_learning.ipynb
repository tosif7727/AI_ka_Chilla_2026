# %% [markdown]
# ### What is Machine Learning?
#
# ### What is Machine Learning?
#
# Machine Learning (ML) is a branch of artificial intelligence (AI) that enables systems to learn and improve from experience without being explicitly programmed. It involves algorithms that can analyze data, identify patterns, and make decisions with minimal human intervention.
#
# ---
#
# ### Types of Machine Learning.
#
# 1. **Supervised Learning** 📊
#     In supervised learning, the model is trained on labeled data, where the input and output are already known. The algorithm learns to map inputs to the correct outputs.
#
#     **Example:**
#     Predicting the price of a house in Karachi 🏠 based on features like location, size, and number of rooms. The training data includes historical house prices with these features.
#
# 2. **Unsupervised Learning** 🔍
#     In unsupervised learning, the model is trained on unlabeled data and tries to find hidden patterns or groupings in the data.
#
#     **Example:**
#     Grouping customers of a Pakistani online shopping platform 🛒 into clusters based on their purchasing behavior to create targeted marketing campaigns.
#
# 3. **Reinforcement Learning** 🎮
#     In reinforcement learning, the model learns by interacting with an environment and receiving rewards or penalties based on its actions.
#
#     **Example:**
#     Training a self-driving car 🚗 to navigate the busy streets of Lahore by rewarding it for avoiding traffic violations and penalizing it for collisions.
#
# 4. **Semi-Supervised Learning** 🧩
#     Semi-supervised learning is a mix of supervised and unsupervised learning, where the model is trained on a small amount of labeled data and a large amount of unlabeled data.
#
#     **Example:**
#     Identifying fake news 📰 on Pakistani social media platforms using a small dataset of labeled fake news articles and a large dataset of unlabeled articles.
#
# 5. **Deep Learning** 🤖
#     Deep learning is a subset of machine learning that uses neural networks with many layers to process complex data.
#
#     **Example:**
#     Developing an Urdu handwriting recognition system ✍️ for digitizing handwritten documents in Pakistan.
#
# ---

# %% [markdown]
# ### Applications of Machine Learning
#
# Machine Learning has a wide range of applications across various industries. Some examples include:
#
# 1. **Healthcare** 🏥
#     - Disease diagnosis and prediction.
#     - Personalized treatment plans.
#     - Drug discovery and development.
#
# 2. **Finance** 💰
#     - Fraud detection in banking transactions.
#     - Stock market prediction.
#     - Credit scoring and risk assessment.
#
# 3. **E-commerce** 🛒
#     - Product recommendation systems.
#     - Customer segmentation and targeted marketing.
#     - Inventory management and demand forecasting.
#
# 4. **Transportation** 🚗
#     - Autonomous vehicles and self-driving cars.
#     - Traffic prediction and optimization.
#     - Route planning and logistics.
#
# 5. **Entertainment** 🎥
#     - Content recommendation on streaming platforms.
#     - Sentiment analysis for movie reviews.
#     - Music and video personalization.
#
# 6. **Agriculture** 🌾
#     - Crop yield prediction.
#     - Pest and disease detection.
#     - Precision farming using IoT and ML.
#
# 7. **Education** 📚
#     - Personalized learning experiences.
#     - Automated grading systems.
#     - Identifying at-risk students for early intervention.
#
# 8. **Social Media** 📱
#     - Fake news detection.
#     - Sentiment analysis of posts and comments.
#     - Content moderation and filtering.
