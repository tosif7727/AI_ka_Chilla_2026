# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# load dataset
df = pd.read_csv('../06_datasets/bank-full.csv', sep=';')

# show sample data
df.sample(5)

# %%
# generate profiling report
profile = ProfileReport(df, title="Bank Marketing Dataset Profiling Report")

# %%
# show report
try:
    profile.to_widgets()
except Exception:
    # Fallback for environments without ipywidgets support
    profile.to_notebook_iframe()

# %%
# profile.to_file("bank_marketing_profile.html")
